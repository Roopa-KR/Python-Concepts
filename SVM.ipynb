# %% [markdown]
# ## SVM : Support Vector Machine
# SVM is a supervised machine learning algorithm used for classification and regression tasks. It works by finding the hyperplane that best separates the data points of different classes in a high-dimensional space.
#
# The goal of SVM is to maximize the margin between the hyperplane and the nearest data points from each class, which are called support vectors. SVM can be used for both linear and non-linear classification by using different kernel functions to transform the data into a higher-dimensional space where it becomes linearly separable.
#
# #it uses the concept of maximizing the margin between the hyperplane and the support vectors to achieve better generalization and improve the performance of the model. SVM can be used for various applications such as image classification, text classification, and bioinformatics.

# %%
Intuition (VERY IMPORTANT)

Imagine two classes:

🔴 Red points
🔵 Blue points

Many lines can separate them… but SVM chooses:

👉 The line with the maximum distance from both classes

That distance = Margin

# %%
Equation of Hyperplane

w⋅x+b=0

Where:

w = weights
x = input
b = bias

# %%
Margin (Most Important Concept)

Margin = distance between hyperplane & nearest points

SVM tries to:

Maximize this margin

# %%
Support Vectors

These are the closest data points to the boundary

They define the hyperplane
If they change → boundary changes

# %% [raw]
# Types of SVM :
# 1. Linear SVM
#      Data is linearly separable
#
#  👉 Example:
#
#  Pass / Fail based on marks
#
# 2. Non-Linear SVM
#  When data is not separable:
#
#  👉 Use Kernel Trick
#
#  Transforms data into higher dimension
#
# 3. Kernel SVM
#
# | Kernel         | Use Case        |
# | -------------- | --------------- |
# | Linear         | Simple data     |
# | Polynomial     | Curved boundary |
# | RBF (Gaussian) | Most common     |
# | Sigmoid        | Neural-like     |

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Sample data
X = [[2], [4], [6], [8]]
y = [0, 0, 1, 1]

# %%
# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Model
model = SVC(kernel='linear')

# %%
# Train
model.fit(X_train, y_train)
