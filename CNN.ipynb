# %% [markdown]
# #CNN : convolutional neural network is a class of deep neural networks, most commonly applied to analyzing visual imagery. They are also known as shift invariant or space invariant artificial neural networks (SIANN), based on their shared-weights architecture and translation invariance characteristics. They have applications in image and video recognition, recommender systems, image classification, medical image analysis, natural language processing, and financial time series.

# %%
#CNN process flow: data xolllection , convolution, pooling, fully connected layer, output layer
# data loading, data preprocessing, model building, model training, model evaluation, model deployment

# %%
#CNN formula:summation of (input * weight) + bias, activation function (ReLU, sigmoid, softmax)

# %%
#Difference between all the activation functions:
#ReLU: Rectified Linear Unit, f(x) = max(0, x),
#Sigmoid: f(x) = 1 / (1 + e^(-x)),
#Softmax: f(x_i) = e^(x_i) / Σ(e^(x_j)) for all j
#tanH: f(x) = (e^(x) - e^(-x)) / (e^(x) + e^(-x))
#The main difference between these activation functions is that ReLU is used for hidden layers, sigmoid is used for binary classification, softmax is used for multi-class classification, and tanH is used for hidden layers when the data is centered around zero.

# %%
#difference between sigmoid and softmax:
#Sigmoid is used for binary classification problems, where the output is a single value between 0 and 1, representing the probability of the positive class. Softmax is used for multi-class classification problems, where the output is a vector of values between 0 and 1, representing the probabilities of each class. The softmax function ensures that the sum of the output probabilities is equal to 1, while the sigmoid function does not have this constraint.  
#difference between ReLU and tanH:
#ReLU is a non-linear activation function that outputs the input directly if it is positive, and outputs zero if it is negative. It is computationally efficient and helps to mitigate the vanishing gradient problem. tanH is also a non-linear activation function that outputs values between -1 and 1, which can help to center the data around zero. However, it can suffer from the vanishing gradient problem, especially for large input values. ReLU is generally preferred for hidden layers in deep neural networks, while tanH can be used when the data is centered around zero.   
#difference between ReLU and sigmoid:       
#ReLU is a non-linear activation function that outputs the input directly if it is positive,    and outputs zero if it is negative. It is computationally efficient and helps to mitigate the vanishing gradient problem. Sigmoid is a non-linear activation function that outputs values between 0 and 1, which can be interpreted as probabilities. However, it can suffer from the vanishing gradient problem, especially for large input values. ReLU is generally preferred for hidden layers in deep neural networks, while sigmoid is used for binary classification problems.
#difference between tanH and sigmoid:
#tanH is a non-linear activation function that outputs values between -1 and 1, which can help to center the data around zero. Sigmoid is a non-linear activation function that outputs values between 0 and 1, which can be interpreted as probabilities. The main difference between tanH and sigmoid is that tanH can output negative values, while sigmoid only outputs positive values. This can make tanH more suitable for hidden layers in deep neural networks, while sigmoid is typically used for binary classification problems.    
#difference between ReLU and softmax:
#ReLU is a non-linear activation function that outputs the input directly if it is positive, and outputs zero if it is negative. It is computationally efficient and helps to mitigate the vanishing gradient problem. Softmax is a non-linear activation function that outputs a vector of values between 0 and 1, representing the probabilities of each class. The main difference between ReLU and softmax is that ReLU is used for hidden layers, while softmax is used for the output layer in multi-class classification problems.

# %%
#building a cnn model to classify images of cats and dogs using.
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 #building a cnn model to classify images of cats and dogs using.
#       2 import tensorflow as tf
# ----> 3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
#       5 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
## Dataset Information

The training archive contains 25,000 images of dogs and cats. Train your algorithm on these files and predict the labels

(1 = dog, 0 = cat).

# %%
# !pip install tensorflow keras
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: keras in c:\users\nisha_classy\anaconda3\lib\site-packages (3.11.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nisha_classy\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Collecting keras
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users
#    ------------------------------- ------- 281.8/350.8 MB 10.5 MB/s eta 0:00:07
#    ------------------------------- ------- 287.3/350.8 MB 10.6 MB/s eta 0:00:06
#    -------------------------------- ------ 292.3/350.8 MB 10.6 MB/s eta 0:00:06
#    --------------------------------- ----- 297.3/350.8 MB 11.0 MB/s eta 0:00:05
#    --------------------------------- ----- 301.2/350.8 MB 11.0 MB/s eta 0:00:05
#    --------------------------------- ----- 304.6/350.8 MB 11.0 MB/s eta 0:00:05
#    ---------------------------------- ---- 309.6/350.8 MB 11.1 MB/s eta 0:00:04
#    ---------------------------------- ---- 314.6/350.8 MB 11.2 MB/s eta 0:00:04
#    ----------------------------------- --- 321.1/350.8 MB 11.2 MB/s eta 0:00:03
#    ------------------------------------ -- 327.4/350.8 MB 11.6 MB/s eta 0:00:03
#    ------------------------------------ -- 332.4/350.8 MB 12.1 MB/s eta 0:00:02
#    ------------------------------------- - 338.4/350.8 MB 12.5 MB/s eta 0:00:01
#    --------------------------------------  343.9/350.8 MB 12.9 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 13.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 13.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 13.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 13.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 350.8/350.8 MB 12.9 MB/s  0:00:29
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 14.5 MB/s  0:00:00
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Installing collected packages: flatbuffers, keras, tensorflow
#
#   Attempting uninstall: flatbuffers
#
#     Found existing installation: flatbuffers 25.2.10
#
#     Uninstalling flatbuffers-25.2.10:
#
#       Successfully uninstalled flatbuffers-25.2.10
#
#   Attempting uninstall: keras
#
#     Found existing installation: keras 3.11.3
#
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#     Uninstalling keras-3.11.3:
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#       Successfully uninstalled keras-3.11.3
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    ------------- -------------------------- 1/3 [keras]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    ---------------------------------------- 3/3 [tensorflow]
#
# Successfully installed flatbuffers-25.12.19 keras-3.14.0 tensorflow-2.21.0
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\nisha_classy\anaconda3\lib\site-packages (3.14.0)
# Requirement already satisfied: absl-py in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in c:\users\nisha_classy\anaconda3\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nisha_classy\anaconda3\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nisha_classy\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Nisha_Classy\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
train_datagen = ImageDataGenerator(
    #Image pixels range: 0–255
    #Neural networks learn better with 0–1
    rescale=1./255,
     #Randomly zooms image in or out by 20%  
     #Why?   
     #Dog may appear big or small in real life.
     #Model learns to recognize dog at any size
    zoom_range=0.2, 
    #Real images are not always straight
    #Helps model handle slanted images
    shear_range=0.2,
    #Dog facing left or right is still a dog
    #Increases dataset size artificially
    horizontal_flip=True
    #THIS WHOLE BLOCK DOES:
    #Normalization
    #Image augmentation
    #Prevents overfitting
)
#this portion will Reads images from folders automatically

train_data = train_datagen.flow_from_directory(
    "dataset/train",
    target_size=(64,64),
    batch_size=4,#Model sees 4 images at a time
    class_mode="binary"
)
